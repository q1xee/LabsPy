#
# Країна підтримує комбінацію ринкової економіки та Скандинавської моделі з обов'язковим медичним страхуванням і комплексною системою соціального страхування. Норвегія має значні запаси нафти, природного газу, мінералів, лісоматеріалів, морепродуктів, прісної води і гідроенергетики. На нафтову промисловість припадає близько чверті валового внутрішнього продукту країни.Норвегія посідає четверте місце у світі в переліку країн за розміром доходу на душу населення, згідно з даними світового банку та МВФ. Країна є найбільшим добувачем нафти і природного газу за межами Середнього Сходу на душу населення. З 2001 до 2006, а також із 2009 до 2014 років, Норвегія мала найвищий індекс людського розвитку у світі. Норвегія також очолює список країн за індексом процвітання вже п'ять років поспіль.
#
# 4 квітня 1949 року Норвегія вступила в блок НАТО. Населення Норвегії двічі на національних референдумах 1972 року і 1994 року відкидало пропозицію про вступ до Європейського Союзу, хоча країна тісно пов'язана з ЄС у межах Європейської економічної та Шенгенської зон.
#
# <h3  align = "center" style="border: solid black 2px; padding: 4px; color: red"> Основна інформація: </h3>
#
# | **Характеристика**               | **Значення**                                                                                  |
# |-----------------------------------|-----------------------------------------------------------------------------------------------|
# | **Столиця**                       | Осло                                                                                          |
# | **Офіційні мови**                 | Норвезька, Саамська                                                                            |
# | **Форма правління**               | Конституційна монархія                                                                         |
# | **Формування**                    | - Королівство Норвегія до об'єднання: 872 <br> - Старе Королівство Норвегія (пік): 1263 <br> - Кальмарська унія: 1397 <br> - Данія-Норвегія: 1524 <br> - Відновлена держава: 25 лютого 1814 <br> - Конституція: 17 травня 1814 <br> - Шведсько-норвезька унія: 4 листопада 1814 <br> - Розірвання унії: 7 червня 1905 <br> - Засновано НАТО: 4 квітня 1949 |
# | **Площа**                        | - Загалом: 385 207 км² (67-ме місце у світі) <br> - Внутр. води: 5,7 %                         |
# | **Населення (оцінка 2024)**       | 5 550 203                                                                                     |
# | **ВВП (ПКС) 2011 р., оцінка**     | - Повний: 265 911 млрд <br> - На душу населення: 97 254                                      |
# | **ВВП (ном.) 2006 рік, оцінка**   | - Повний: 335,3 млрд <br> - На душу населення: 72,305.6                                     |
# | **ІЛР (2022)**                    | 0.966 (високий)                                                                               |
# | **Валюта**                        | Норвезька крона (NOK)                                                                          |
#
# <h3  align = "center" style="border: solid black 2px; padding: 4px; color: red"> Пам'ятки природи та культури: </h3>
#
# ### 1. Гейрангер-фьорд
#
# <img src="Geirangerfjorden.jfif" alt="Geirangerfjorden" width="520" height="320">
#
# Величні водоспади, стрімкі скелі, висотою близько півтора кілометрів, білосніжні льодовики і занедбані ферми, розташовані на невеликих гірських майданчиках, надають чарівності одному з наймальовничіших фіордів Норвегії. Розташований поруч Музей фіордів знайомить туристів з географічним життям країни.
#
# ### 2. Рьорус
#
# <img src="https://sights.com.ua/wp-content/uploads/2022/08/x20-glavnyh-dostoprimechatelnostej-norvegii-b24d583.jpg.pagespeed.ic.mfZzs46Gzt.webp" width=520>
#
# Крихітне норвезьке місто, відоме з XVII століття як центр розробки міді, до сих пір зберігає свою історичну спадщину: його центр представлений унікальними дерев’яними будинками, побудованими кілька століть назад. Місцевий художник Х.Сольберг дуже любив Рьорус і часто малював місто з прилеглими до нього околицями.
#
# ### 3. Ставкірка в Урнесі
#
# <img src="https://sights.com.ua/wp-content/uploads/2022/08/x20-glavnyh-dostoprimechatelnostej-norvegii-7e4f978.jpg.pagespeed.ic.1sr9dSPcmo.webp" width="520">
#
# Зведена на початку XII століття дерев’яна церква в Урнесі є яскравим зразком унікального « звіриного стилю », що характеризується асиметричністю орнаменту і використанням тварин мотивів. Існує версія, що на різьблених панелях храму відображені сюжети зі скандинавської міфології.
#
# ### 4. Музей кораблів вікінгів
#
# <img src="https://sights.com.ua/wp-content/uploads/2022/08/x20-glavnyh-dostoprimechatelnostej-norvegii-6b5a558.jpg.pagespeed.ic.dM2M84BWoB.webp" width="520">
#
# У будівлі початку XX століття, що стоїть на півострові Бюгдьо, можна побачити три величезних корабля вікінгів, побудованих в IX столітті і знайдених через тисячу років в водах Осло. На грандіозних корабельних спорудах присутні предмети що також входять в музейну колекцію: старовинні дерев’яні санки і вози, посуд, домашній скарб і фрагменти тканин – все це сьогодні може побачити кожен бажаючий.
#
# ### 5. Язик Тролля
#
# <img src="https://sights.com.ua/wp-content/uploads/2022/08/20-glavnyh-dostoprimechatelnostej-norvegii-decd5eb.jpg" width="520">
#
# Виступаюча ділянка скелі Скьеггедаль розташована далеко від класичних туристичних маршрутів дуже нагадує гігантський язик. Щоб дістатися до нього потрібно витратити п’ять годин і більшу частину часу доведеться йти в гору. З Язику Троля відкривається чудовий краєвид на озеро Рінгедалсватн, розташоване в трьохстах п’ятдесяти метрах нижче скелі.
#
# <h3  align = "center" style="border: solid black 2px; padding: 4px; color: red"> Видатні персоналії: </h3>
#
# * ### Едвард Мунк
# *Норвезький художник, найбільш відомий своїми роботами: «Крик», «Мадонна» та «Хвора дитина»*
#
# <img src="https://www.thefamouspeople.com/profiles/thumbs/edvard-munch-1.jpg" width="320">
#
# |                  |                     |
# |------------------|---------------------|
# | Дата народження  | 12 грудня 1863 року |
# | Знак зодіаку     | Стрілець            |
# | Місце народження | Летен               |
# | Помер            | 1944 р.             |
#
# Едвард Мунк, норвезький художник, відомий своїм впливовим і самобутнім стилем. Він навчався в Королівській школі мистецтва та дизайну в Осло, де занурився в богемний стиль життя і розвинув свій підхід до «живопису душі». Подорожі до Парижа та Берліна відкрили йому нові впливи та техніки, що призвело до створення його знаменитої серії «Фриз життя». Його знакова робота «Крик» відображає екзистенційний страх сучасного життя і стала символом його мистецького бачення. Незважаючи на проблеми з психічним здоров'ям, слава та мистецька репутація Мунка неухильно зростали, що увінчалося створенням тривалої спадщини.
#
# * ### Руаль Амундсен
# *Норвезький дослідник, який першим досяг Південного полюса*
#
# <img src="https://www.thefamouspeople.com/profiles/thumbs/roald-amundsen-1.jpg" width="320">
#
# |                  |                     |
# |------------------|---------------------|
# | Дата народження  | 16 липня 1872 року  |
# | Знак зодіаку     | Рак                 |
# | Місце народження | Борге               |
# | Помер            | 18 червня 1928 р.   |
#
# Роальд Амундсен, норвезький дослідник, відомий своїми новаторськими експедиціями в полярні регіони під час героїчної епохи освоєння Антарктики. Він здійснив видатний подвиг, очоливши першу експедицію, яка перетнула Північно-Західний прохід, і був першою людиною, яка досягла Південного полюса в 1911 році. Крім того, у 1926 році Амундсен брав участь у повітряній експедиції на Північний полюс. Його відданість дослідженню та винахідливі стратегії вирішення проблем міцно закріпили за ним славу одного з найбільш шанованих полярних дослідників в історії.
#
# * ### Петер Сольберґ
# *Ралійний гонщик*
#
# <img src="https://www.thefamouspeople.com/profiles/thumbs/petter-solberg-1.jpg" width="320">
#
# |                  |                         |
# |------------------|-------------------------|
# | Дата народження  | 18 листопада 1974 року  |
# | Знак зодіаку     | Скорпіон                |
# | Місце народження | Аскім                   |
#
# Петтер Сольберг - норвезький гонщик-пенсіонер з ралі та ралі-кросу. Він розпочав свою кар'єру в чемпіонаті світу з ралі в 1998 році в команді Ford, а пізніше приєднався до команди Subaru World Rally Team. У 2002 році Сольберг фінішував другим, у 2003 році завоював титул чемпіона світу серед пілотів, а після виходу з команди Subaru заснував Petter Solberg World Rally Team за приватної підтримки. У 2012 році він повернувся до команди Ford World Rally Team, а в 2013 році переключився на ралі-крос. У 2014 та 2015 роках Сольберг став чемпіоном світу з ралі-кросу за версією FIA, а у 2018 році пішов на пенсію.
#
# * ### Аксель Лунд Свіндаль
# *Гірськолижний гонщик*
#
# <img src="https://www.thefamouspeople.com/profiles/thumbs/aksel-lund-svindal-1.jpg" width="320">
#
# |                  |                     |
# |------------------|---------------------|
# | Дата народження  | 26 грудня 1982 року |
# | Знак зодіаку     | Козеріг             |
# | Місце народження | Льоренског          |
#
# Аксель Лунд Свіндаль - видатний норвезький гірськолижник-пенсіонер з видатною кар'єрою, сповненою численних досягнень. Він здобув численні нагороди, включаючи два загальних чемпіонати Кубка світу, кілька золотих олімпійських медалей і п'ять титулів чемпіона світу в різних дисциплінах. Свіндаль увійшов в історію, ставши першим чоловіком-гірськолижником, який виграв титули на чотирьох чемпіонатах світу поспіль. Відомий як один з найкращих норвезьких гірськолижників, він завершив змагальну кар'єру після Чемпіонату світу з гірськолижного спорту 2019 року.

# %%
# %%HTML
# <svg width="220" height="160">
#   <!-- Червоний фон -->
#     <rect width="220" height="160" fill="#BA0C2F"/>
#
#   <!-- Білий хрест -->
#     <rect x="60" width="40" height="160" fill="white"/>
#     <rect y="60" width="220" height="40" fill="white"/>
#
#   <!-- Синій хрест -->
#     <rect x="70" width="20" height="160" fill="#00205B"/>
#     <rect y="70" width="220" height="20" fill="#00205B"/>
# </svg>
# Out:
# <svg width="220" height="160">
#   <!-- Червоний фон -->
#     <rect width="220" height="160" fill="#BA0C2F"/>
#
#   <!-- Білий хрест -->
#     <rect x="60" width="40" height="160" fill="white"/>
#     <rect y="60" width="220" height="40" fill="white"/>
#
#   <!-- Синій хрест -->
#     <rect x="70" width="20" height="160" fill="#00205B"/>
#     <rect y="70" width="220" height="20" fill="#00205B"/>
# </svg>

# %%
import math

def task_10():
    try:
        # Введення числа N
        N = int(input("Введіть число N: "))
        
        # Перевірка на від'ємність
        if N < 0:
            return "Від'ємне число не можна представити як суму квадратів цілих чисел."

        # Перевіряємо всі можливі значення a від 1 до sqrt(N)
        for a in range(1, int(math.sqrt(N)) + 1):
            a_squared = a * a
            # Залишок після віднімання a^2 від N
            remainder = N - a_squared
            
            # Перевіряємо, чи залишок є квадратом натурального числа
            if remainder > 0:
                b = int(math.sqrt(remainder))
                if b * b == remainder:
                    # Формуємо рядок для виводу результату
                    return f"{a}^2 + {b}^2 = {N}"
        
        # Якщо не знайшли відповідних чисел
        return f"Число {N} не можна представити квадратами цілих чисел"
    
    except ValueError:
        return "Будь ласка, введіть ціле число."

# Виклик функції для перевірки

# %%
task_10()
# Out:
# Введіть число N: 8
# '2^2 + 2^2 = 8'
